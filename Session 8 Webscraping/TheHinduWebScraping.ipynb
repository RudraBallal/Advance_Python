# %% [markdown]
# ## The Hindu E-Paper WebScraping

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.thehindu.com/opinion/editorial/"
data = requests.get(url)
data
# Out:
# <Response [200]>

# %% [markdown]
# #### when response is 200 then it is ok.

# %%
data.content
# Out:
# b'<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en"><head><link rel="alternate" type="application/rss+xml" href="https://www.thehindu.com/opinion/editorial/feeder/default.rss"><title>\n\tEditorials, Editorial Opinions, Editorial News, The Hindu Opinion - The Hindu\n</title><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="title" content="Editorials, Editorial Opinions, Editorial News, The Hindu Opinion" /><meta name="description" content="Read the latest opinion editorials from The Hindu, offering insightful analysis and diverse perspectives on current affairs, politics, social issues, and more. " /><meta name="robots" content="index, follow" /><meta name="robots" content="max-image-preview:large"><meta name="atdlayout" content="sectionpage" /><meta name="twitter:title" content="Editorials, Editorial Opinions, Editorial News, The Hindu Opinion"><meta
# ...

# %%
bs = BeautifulSoup(data.content)
bs
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><link href="https://www.thehindu.com/opinion/editorial/feeder/default.rss" rel="alternate" type="application/rss+xml"/><title>
# 	Editorials, Editorial Opinions, Editorial News, The Hindu Opinion - The Hindu
# ...

# %%
headings = bs.find_all('h3',class_ = "title")
headings
# Out:
# [<h3 class="title"><a href="https://www.thehindu.com/opinion/editorial/forest-pitch-the-hindu-editorial-on-the-2023-chhattisgarh-assembly-elections/article67423695.ece"><strong>
#  Forest pitch: On the Chhattisgarh Assembly elections </strong></a></h3>,
#  <h3 class="title"><a href="https://www.thehindu.com/opinion/editorial/olympian-heights-the-hindu-editorial-on-indias-efforts-to-organise-the-2036-olympics/article67423709.ece"><strong>
#  Olympian heights: On India’s efforts to organise the 2036 edition </strong></a></h3>,
#  <h3 class="title"><a href="https://www.thehindu.com/opinion/editorial/balancing-policy-the-hindu-editorial-on-israel-palestine-and-indias-line/article67417504.ece"><strong>
#  Balancing policy: On Israel, Palestine and India’s line </strong></a></h3>,
#  <h3 class="title"><a href="https://www.thehindu.com/opinion/editorial/triangular-contest-on-the-mizoram-assembly-elections-in-november-2023/article67416992.ece"><strong>
# ...

# %% [markdown]
# ### Getting the url's

# %%
headings[0].find('a').get('href')
# Out:
# 'https://www.thehindu.com/opinion/editorial/forest-pitch-the-hindu-editorial-on-the-2023-chhattisgarh-assembly-elections/article67423695.ece'

# %% [markdown]
# ## Create a function to fetch all new article

# %%
def get_news_urls(url):
    data = requests.get(url)
    bs = BeautifulSoup(data.content)
    headings = bs.find_all('h3',class_= "title")
    links = []
    for i in headings:
        s = i.find('a').get('href')
        links.append(s)
    return links

# %%
url
# Out:
# 'https://www.thehindu.com/opinion/editorial/'

# %%
links = get_news_urls(url)
links
# Out:
# ['https://www.thehindu.com/opinion/editorial/forest-pitch-the-hindu-editorial-on-the-2023-chhattisgarh-assembly-elections/article67423695.ece',
#  'https://www.thehindu.com/opinion/editorial/olympian-heights-the-hindu-editorial-on-indias-efforts-to-organise-the-2036-olympics/article67423709.ece',
#  'https://www.thehindu.com/opinion/editorial/balancing-policy-the-hindu-editorial-on-israel-palestine-and-indias-line/article67417504.ece',
#  'https://www.thehindu.com/opinion/editorial/triangular-contest-on-the-mizoram-assembly-elections-in-november-2023/article67416992.ece',
#  'https://www.thehindu.com/opinion/editorial/jaipur-gamble-the-hindu-editorial-on-the-2023-rajasthan-assembly-elections/article67412814.ece',
#  'https://www.thehindu.com/opinion/editorial/vendetta-without-limit-the-hindu-editorial-on-the-resurrection-of-an-old-case-against-arundhati-roy-and-an-academician/article67412339.ece',
# ...

# %%
len(links)
# Out:
# 21

# %% [markdown]
# ## For url fetch the news headings

# %%
links[0]
# Out:
# 'https://www.thehindu.com/opinion/editorial/forest-pitch-the-hindu-editorial-on-the-2023-chhattisgarh-assembly-elections/article67423695.ece'

# %%
data2 = requests.get(links[0])
data2
# Out:
# <Response [200]>

# %%
bs2 = BeautifulSoup(data2.content)

# %%
h = bs2.find('h1',class_ = "title").text
h
# Out:
# '\nForest pitch: On the Chhattisgarh Assembly elections\n'

# %%
t = bs2.find('p',class_ = "publish-time").text
t
# Out:
# ' October 16, 2023 12:20 am | Updated 08:21 am IST '

# %%
content = bs2.find_all('p')
content
# Out:
# [<p class="btn-title">To enjoy additional benefits</p>,
#  <p class="connect-us">CONNECT WITH US</p>,
#  <p class="publish-time"> October 16, 2023 12:20 am | Updated 08:21 am IST </p>,
#  <p class="comments"><span class="coral-count" data-coral-id="67423695" data-coral-notext="true" data-coral-url="https://www.thehindu.com/opinion/editorial/forest-pitch-the-hindu-editorial-on-the-2023-chhattisgarh-assembly-elections/article67423695.ece"></span>
#  COMMents
#  </p>,
#  <p class="share share-text"> SHARE
#  </p>,
#  <p class="read-later" data-articleid="67423695" style="display:none">
#  READ LATER
#  </p>,
# ...

# %%
content[0].text
# Out:
# 'To enjoy additional benefits'

# %%
news = ""
for i in content:
    news = news + i.text

# %%
print(news)
# Out:
# To enjoy additional benefitsCONNECT WITH US October 16, 2023 12:20 am | Updated 08:21 am IST
# COMMents
#  SHARE
#
# READ LATER
# ...

# %%
def get_details(url):
    data2 = requests.get(url)
    bs2 = BeautifulSoup(data2.content)
    h = bs2.find('h1',class_ = "title").text
    t = bs2.find('p',class_ = "publish-time").text
    cont = bs2.find_all('p')
    news = ""
    for i in cont:
        news = news + i.text
    return h,t,news

# %%
links[0
      ]
# Out:
# 'https://www.thehindu.com/opinion/editorial/forest-pitch-the-hindu-editorial-on-the-2023-chhattisgarh-assembly-elections/article67423695.ece'

# %%
h,t,news = get_details(links[0])

# %%
h
# Out:
# '\nForest pitch: On the Chhattisgarh Assembly elections\n'

# %%
t
# Out:
# ' October 16, 2023 12:20 am | Updated 08:21 am IST '

# %%
news
# Out:
# 'To enjoy additional benefitsCONNECT WITH US October 16, 2023 12:20 am | Updated 08:21 am IST \nCOMMents\n SHARE\n\nREAD LATER\nIn Chhattisgarh, the ruling Congress has built an election plank with a mix of regional pride and welfarism. The Bharatiya Janata Party, its principal opponent, is targeting the government on corruption and non-fulfilment of election promises made five years ago. The Congress’s attempts to build a narrative around Chhattisgarhi sub-nationalism have made regional identity a key electoral theme for the first time since the State was formed in 2000. The party is also relying on its direct benefit transfer schemes such as the Rajiv Gandhi Kisan Nyay Yojana or the Godhan Nyay Yojana, or higher prices on minor forest produce that cover a major chunk of the rural and tribal populace. Rural housing is another issue that has been hotly contested with both sides accusing the other of being ineffective and insensitive in this regard. A government survey that has pegged
# ...

# %% [markdown]
# ## Saving all the data into DataFrame

# %%
import pandas as pd
def get_news_dataframe(url):
    # Get news links
    links = get_news_urls(url)
    date = []
    title = []
    article = []
    # Get news details
    for i in links:
        h,t,news = get_details(i)
        title.append(h)
        date.append(t)
        article.append(news)
        # Create a Dictionary
    dct = {'Date':date,
           'Heading':title,
           'News':article,
           'url':links}
    # Create a DataFrame
    df = pd.DataFrame(dct)
    return df

# %%
url
# Out:
# 'https://www.thehindu.com/opinion/editorial/'

# %%
df = get_news_dataframe(url)
df
# Out:
#                                                  Date  \
# 0    October 16, 2023 12:20 am | Updated 08:21 am ...
# 1    October 16, 2023 12:10 am | Updated 12:10 am ...
# 2    October 14, 2023 12:20 am | Updated October 1...
# 3    October 14, 2023 12:10 am | Updated 08:32 am ...
# 4    October 13, 2023 12:20 am | Updated 12:20 am ...
# 5    October 13, 2023 12:10 am | Updated 10:39 am ...
# 6    October 12, 2023 12:20 am | Updated 04:22 pm ...
# 7    October 12, 2023 12:10 am | Updated 09:05 am ...
# 8    October 11, 2023 12:20 am | Updated 12:20 am ...
# 9    October 11, 2023 12:10 am | Updated 10:55 am ...
# 10   October 10, 2023 12:20 am | Updated 10:10 am ...
# 11   October 10, 2023 12:10 am | Updated 07:32 am ...
# 12   October 09, 2023 12:20 am | Updated 10:13 pm ...
# 13   October 09, 2023 12:15 am | Updated 12:15 am ...
# 14   October 07, 2023 12:15 am | Updated 08:05 am ...
# 15   October 07, 2023 12:15 am | Updated 11:47 am ...
# ...

# %% [markdown]
# ### Save this to CSV file

# %%
df.to_csv('TheHinduNews.csv')
